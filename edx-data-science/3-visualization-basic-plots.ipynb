# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot') #

# %% [markdown]
# ## Histograms

# %% [markdown]
# ### Students data

# %%
student_dataset = pd.read_csv('./data/students.data', index_col=0)
student_dataset.head()
# Out:
#     sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  studytime  \
# id
# 0     1   18        0        1        0     4     4           2          2
# 1     1   17        0        1        1     1     1           1          2
# 2     1   15        0        0        1     1     1           1          2
# 3     1   15        0        1        1     4     2           1          3
# 4     1   16        0        1        1     3     3           1          2
#
#     failures ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1  \
# id           ...
# 0          0 ...       4         3      4     1     1       3         4   0
# 1          0 ...       5         3      3     1     1       3         2   9
# 2          0 ...       4         3      2     2     3       3         6  12
# 3          0 ...       3         2      2     1     1       5         0  14
# 4          0 ...       4         3      2     1     2       5         0  11
#
#     G2  G3
# id
# 0   11  11
# ...

# %%
my_series = student_dataset.G3  # series 
my_series.plot.hist(alpha=0.5)
plt.xlabel('G3')
plt.ylabel('# of students')
plt.title('Student G3')
#my_series.plot.hist(alpha=0.5,bins=20)
#my_series.plot.hist(alpha=0.5,bins=[0,5,10,15,20])
# Out:
# Text(0.5,1,'Student G3')

# %%
my_dataframe = student_dataset[['G3','G2','G1']] # extract columns into new data frame 
#my_dataframe.plot.hist(alpha=0.5)
#my_dataframe.plot.hist(alpha=0.5, normed=True)
#my_dataframe.plot.hist(alpha=0.5, normed=True, cumulative=False)
#my_dataframe.plot.hist(alpha=0.5, stacked=True)
#my_dataframe.plot.hist(alpha=0.5, stacked=True, log=True)
#my_dataframe.plot.hist(alpha=0.5, stacked=True, orientation='horizontal')
my_dataframe.plot.hist(alpha=0.9, stacked=False, orientation='horizontal', histtype='step')

# %% [markdown]
# ### Wheat data

# %%
df = pd.read_csv('./data/wheat.data', index_col=0)
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
df[df.wheat_type=='rosa'].asymmetry.plot.hist(alpha=0.4)
df[df.wheat_type=='kama'].asymmetry.plot.hist(alpha=0.4)
df[df.wheat_type=='canadian'].asymmetry.plot.hist(alpha=0.4)
plt.legend(['rosa','kama','canadian'])

# %% [markdown]
# ## 2D Scatter Plots

# %%
student_dataset.plot.scatter(x='G1',y='G3')
plt.suptitle('G1-G3 relationship')
# Out:
# Text(0.5,0.98,'G1-G3 relationship')

# %%
# Difficult to make multiple plots overlay
student_dataset.plot.scatter(x='G1',y='G2',marker='v', color='r')
student_dataset.plot.scatter(x='G1',y='G3',marker='x', color='g')

# %%
# Matplotlib.plt can take either Numpy.NArray or Pandas.Series
g1 = student_dataset.G1
g2 = student_dataset.G2
g3 = student_dataset.G3

"""
# To take numpy.nArray..... 
g1 = student_dataset.G1.values
g2 = student_dataset.G2.values
g3 = student_dataset.G3.values
"""

plt.scatter(x=g1,y=g2, color='m',label='G2', marker='v', alpha=0.5)
plt.scatter(x=g1,y=g3, color='c',label='G3', marker='x', alpha=0.5)
plt.xlabel('G1')
plt.ylabel('G2/G3')
plt.legend()

# %% [markdown]
# ## 3D Scatter Plots

# %%
# %matplotlib notebook    
# %matplotligb inline 
# %matplotlib gtk
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # Axes3D used
ax.set_xlabel('Final Grade')
ax.set_ylabel('First Grade')
ax.set_zlabel('Dailiy Alcohol')

ax.scatter( student_dataset.G1, student_dataset.G3, student_dataset.Dalc, c='r', marker='o')
# Out:
# <img src="data:image/png;base64,..." width="640">
